# %%
# loading necessary modules
from __future__ import print_function
import numpy as np
import os
os.environ['OMP_NUM_THREADS'] = '1'
os.environ['MKL_NUM_THREADS'] = '1'
# loading rect_maxvol itself
from rect_maxvol import rect_maxvol, rect_maxvol_qr, rect_maxvol_svd, maxvol, maxvol_qr, maxvol_svd
from rect_maxvol.rect_maxvol import py_rect_maxvol, c_rect_maxvol, py_maxvol, c_maxvol

np.random.seed(100)
a = np.random.rand(1000, 30, 2).view(dtype=np.complex128)[:,:,0]
top_k_index = 50

# %%
# check maxvol, maxvol_qr and maxvol_svd with dtype=np.complex128

print('----------MAXVOL--------------')
piv, C = maxvol(a, 1.0)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol(a, 1.0, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol(a, 1.05)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol(a, 1.05, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol(a, 1.10)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol(a, 1.10, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

print('----------MAXVOL_QR--------------')
piv, C = maxvol_qr(a, 1.0)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_qr(a, 1.0, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_qr(a, 1.05)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_qr(a, 1.05, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_qr(a, 1.10)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_qr(a, 1.10, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

print('----------MAXVOL_SVD--------------')
piv, C = maxvol_svd(a, svd_tol = 1e-1, tol = 1.0, job = 'R')
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_svd(a, svd_tol = 1e-1, tol = 1.0, job = 'R', top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_svd(a, svd_tol = 1e-1, tol = 1.05, job = 'R')
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_svd(a, svd_tol = 1e-1, tol = 1.05, job = 'R', top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_svd(a, svd_tol = 1e-1, tol = 1.10, job = 'R')
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))

piv, C = maxvol_svd(a, svd_tol = 1e-1, tol = 1.10, job = 'R', top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('Chebyshev norm of matrix C: {}'.format(abs(C).max()))
# Out:
# ----------MAXVOL--------------
# relative maxvol approximation error: 1.1169921841e-15
# Chebyshev norm of matrix C: 1.0
# relative maxvol(top_k_index=50) approximation error: 9.64838768662e-16
# Chebyshev norm of matrix C: 1.5167022859
# relative maxvol approximation error: 1.20365952104e-15
# Chebyshev norm of matrix C: 1.0464068226
# relative maxvol(top_k_index=50) approximation error: 7.99496896657e-16
# Chebyshev norm of matrix C: 1.5167022859
# relative maxvol approximation error: 9.97068873972e-16
# Chebyshev norm of matrix C: 1.07853911436
# relative maxvol(top_k_index=50) approximation error: 7.99496896657e-16
# Chebyshev norm of matrix C: 1.5167022859
# ----------MAXVOL_QR--------------
# relative maxvol approximation error: 1.42187726922e-15
# Chebyshev norm of matrix C: 1.0
# relative maxvol(top_k_index=50) approximation error: 1.04908587745e-14
# Chebyshev norm of matrix C: 1.5167022859
# relative maxvol approximation error: 1.45909734856e-15
# Chebyshev norm of matrix C: 1.0464068226
# relative maxvol(top_k_index=50) approximation error: 1.0471074292e-14
# Chebyshev norm of matrix C: 1.5167022859
# relative maxvol approximation error: 1.10355731792e-15
# Chebyshev norm of matrix C: 1.07853911436
# relative maxvol(top_k_index=50) approximation error: 1.0471074292e-14
# Chebyshev norm of matrix C: 1.5167022859
# ----------MAXVOL_SVD--------------
# relative maxvol approximation error: 0.246839403405
# Chebyshev norm of matrix C: 1.0
# relative maxvol(top_k_index=50) approximation error: 0.333266853853
# Chebyshev norm of matrix C: 1.4352228629
# relative maxvol approximation error: 0.246839403405
# Chebyshev norm of matrix C: 1.0
# relative maxvol(top_k_index=50) approximation error: 0.374642298087
# Chebyshev norm of matrix C: 1.59865468691
# relative maxvol approximation error: 0.25484511962
# Chebyshev norm of matrix C: 1.06824913975
# relative maxvol(top_k_index=50) approximation error: 0.374642298087
# Chebyshev norm of matrix C: 1.59865468691

# %%
# check rect_maxvol, rect_maxvol_qr and rect_maxvol_svd with dtype=np.complex128

print('----------RECT_MAXVOL--------------')
piv, C = rect_maxvol(a, 1.0)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol(a, 1.0, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol(a, 1.5)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol(a, 1.5, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol(a, 2.0)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol(a, 2.0, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

print('----------RECT_MAXVOL_QR--------------')
piv, C = rect_maxvol_qr(a, 1.0)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_qr(a, 1.0, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_qr(a, 1.5)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_qr(a, 1.5, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_qr(a, 2.0)
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_qr(a, 2.0, top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

print('----------RECT_MAXVOL_SVD--------------')
piv, C = rect_maxvol_svd(a, svd_tol = 1e-1, tol = 1.0, job = 'R')
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_svd(a, svd_tol = 1e-1, tol = 1.0, job = 'R', top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_svd(a, svd_tol = 1e-1, tol = 1.5, job = 'R')
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_svd(a, svd_tol = 1e-1, tol = 1.5, job = 'R', top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_svd(a, svd_tol = 1e-1, tol = 2.0, job = 'R')
print('relative maxvol approximation error: {}'.format(np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))

piv, C = rect_maxvol_svd(a, svd_tol = 1e-1, tol = 2.0, job = 'R', top_k_index = top_k_index)
print('relative maxvol(top_k_index={}) approximation error: {}'.format(top_k_index, np.linalg.norm(a-C.dot(a[piv]), 2)/np.linalg.norm(a, 2)))
print('maximum euclidian norm of row in matrix C: {}'.format(max([np.linalg.norm(C[i], 2) for i in range(1000)])))
# Out:
# ----------RECT_MAXVOL--------------
# relative maxvol approximation error: 7.54286006916e-16
# maximum euclidian norm of row in matrix C: 1.0
# relative maxvol(top_k_index=50) approximation error: 8.41410002311e-16
# maximum euclidian norm of row in matrix C: 1.91251933784
# relative maxvol approximation error: 7.8885418046e-16
# maximum euclidian norm of row in matrix C: 1.47552960395
# relative maxvol(top_k_index=50) approximation error: 6.43987295768e-16
# maximum euclidian norm of row in matrix C: 2.28018146409
# relative maxvol approximation error: 7.08572536591e-16
# maximum euclidian norm of row in matrix C: 1.98552688328
# relative maxvol(top_k_index=50) approximation error: 6.16289764788e-16
# maximum euclidian norm of row in matrix C: 2.928903005
# ----------RECT_MAXVOL_QR--------------
# relative maxvol approximation error: 1.07749427297e-15
# maximum euclidian norm of row in matrix C: 1.0
# relative maxvol(top_k_index=50) approximation error: 4.25985188754e-15
# maximum euclidian norm of row in matrix C: 1.91251933784
# relative maxvol approximation error: 1.08883486393e-15
# maximum euclidian norm of row in matrix C: 1.47552960395
# relative maxvol(top_k_index=50) approximation error: 5.32819653654e-15
# maximum euclidian norm of row in matrix C: 2.28018146409
# relative maxvol approximation error: 1.05385115169e-15
# maximum euclidian norm of row in matrix C: 1.98552688328
# relative maxvol(top_k_index=50) approximation error: 7.04612741779e-15
# maximum euclidian norm of row in matrix C: 2.928903005
# ----------RECT_MAXVOL_SVD--------------
# relative maxvol approximation error: 0.144971725468
# maximum euclidian norm of row in matrix C: 1.0
# relative maxvol(top_k_index=50) approximation error: 0.213163222056
# maximum euclidian norm of row in matrix C: 1.65295782274
# relative maxvol approximation error: 0.188467784134
# maximum euclidian norm of row in matrix C: 1.40581472836
# relative maxvol(top_k_index=50) approximation error: 0.292329231286
# maximum euclidian norm of row in matrix C: 2.37318045972
# relative maxvol approximation error: 0.226263343861
# maximum euclidian norm of row in matrix C: 1.85668430673
# relative maxvol(top_k_index=50) approximation error: 0.339233426863
# maximum euclidian norm of row in matrix C: 2.81158100054
